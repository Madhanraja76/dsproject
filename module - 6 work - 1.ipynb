# %%
import pandas as pd
import numpy as ny
dataset = pd.read_csv("C:/Users/ELCOT/Downloads/WORK VI/prisoners.csv")
dataset["total benifited"] = dataset.iloc[:,2:6].sum(axis=1)
dataset.loc["Total"]=dataset.iloc[:,2:5].sum()
dataset
# Out:
#                 STATE/UT    YEAR  \
# 0         Andhra Pradesh  2013.0
# 1      Arunachal Pradesh  2013.0
# 2                  Assam  2013.0
# 3                  Bihar  2013.0
# 4            Chhatisgarh  2013.0
# 5                    Goa  2013.0
# 6                Gujarat  2013.0
# 7                Haryana  2013.0
# 8       Himachal Pradesh  2013.0
# 9        Jammu & Kashmir  2013.0
# 10             Jharkhand  2013.0
# 11             Karnataka  2013.0
# 12                Kerala  2013.0
# 13        Madhya Pradesh  2013.0
# 14           Maharashtra  2013.0
# 15               Manipur  2013.0
# 16             Meghalaya  2013.0
# 17               Mizoram  2013.0
# 18              Nagaland  2013.0
# 19                Orissa  2013.0
# 20                Punjab  2013.0
# 21             Rajasthan  2013.0
# 22                Sikkim  2013.0
# 23             Tamilnadu  2013.0
# 24               Tripura  2013.0
# 25         Uttar Pradesh  2013.0
# 26           Uttaranchal  2013.0
# ...

# %%
import matplotlib.pyplot as plt
dataset = pd.read_csv("C:/Users/ELCOT/Downloads/WORK VI/prisoners.csv")
dataset['Total Benificiary'] = dataset.iloc[:, 2:6].sum(axis=1)
x = dataset["STATE/UT"]
y = dataset["Total Benificiary"]
plt.bar(x,y,color='red')
plt.show()
print("Andhra pradesh as maximum number of Benificiary ")
plt.pie(c)
plt.show()
# Out:
# Andhra pradesh as maximum number of Benificiary
